# %%
from imgtools import *
from PIL import Image

# %%
dir = 'C:/Users/USER/TGMT/Image'
image_path = dir + '/2.jpg'

# %%
img = load_image(image_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=380x379>

# %%
rotated_image = img.rotate(90)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=380x379>

# %%
transposed_image = img.transpose(Image.Transpose.ROTATE_90)
display(transposed_image)
# Out:
# <PIL.Image.Image image mode=RGB size=379x380>
