# %%
from imgtools import *
from PIL import Image

# %%
dir = 'C:/Users/USER/TGMT/Image'
image_path = dir + '/1.jpg'

# %%
img = load_image(image_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=288x345>

# %%
gray_image = img.convert("L")
display(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=288x345>

# %%
red_band, green_band, blue_band = img.split()
display(red_band)
display(green_band)
display(blue_band)
# Out:
# <PIL.Image.Image image mode=L size=288x345>
# <PIL.Image.Image image mode=L size=288x345>
# <PIL.Image.Image image mode=L size=288x345>

# %%
merged_image =  Image.merge("RGB", (red_band, green_band, blue_band))
display(merged_image)
# Out:
# <PIL.Image.Image image mode=RGB size=288x345>
