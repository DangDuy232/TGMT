# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
my_path = 'D:/TGMT/Image/1.jpg'

im = Image.open(my_path)
plt.imshow(im)

# %%
im_gray = im.convert('L')
plt.imshow(im_gray, cmap='gray')

# %%
im_array = np.array(im_gray)
print(im_array)
# Out:
# [[139 139 138 ... 107 107 107]
#  [135 135 134 ... 107 107 107]
#  [132 132 133 ... 107 107 107]
#  ...
#  [215 218 220 ...  50  48  47]
#  [215 218 220 ...  61  59  59]
#  [215 218 220 ...  71  70  69]]

# %%
plt.figure()
plt.hist(im_array.flatten(), bins=128)
plt.title('Biểu đồ Histogram của ảnh')
plt.xlabel('Giá trị của pixel')
plt.ylabel('Số lượng')
plt.show()

# %%
plt.figure()
plt.gray()
plt.contour(im_gray, origin="image")
plt.show()

# %%
my_path = 'D:/TGMT/Image/2.jpg'

im = Image.open(my_path).convert("L")

plt.imshow(im)

plt.figure()

plt.gray()

plt.contour(im, origin="image")

plt.axis('equal')
plt.show()
