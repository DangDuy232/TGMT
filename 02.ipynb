# %%
from imgtools import *

# %%
my_dir= 'C:/Users/USER/TGMT/Image'

# %%
imgs =  get_image_list(my_dir)

# %%
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (288, 345)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=288x345>
# (380, 379)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=380x379>
# (288, 345)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=288x345>
# (288, 345)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=288x345>
